# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Install Required Packages

# %%
# !pip install evaluate datasets
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.26.4)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.6)
# Collecting xxhash (from evaluate)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2021.05.0 (from fsspec[http]>=2021.05.0->evaluate)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 3.9 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 14.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.6 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.8 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.4 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets, evaluate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 evaluate-0.4.3 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %% [markdown]
# # Import Required Packages

# %%
import os
import evaluate
import pandas as pd
import numpy as np

import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader
from peft import LoraConfig, TaskType, get_peft_model
from transformers import AutoTokenizer, TrainingArguments, Trainer, DataCollatorWithPadding, AutoModelForSequenceClassification
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
from datasets import load_dataset
from scipy.special import softmax

# %% [markdown]
# # Set Environment

# %%
seed = 2024
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.use_deterministic_algorithms(False)
# Out:
# cuda

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Load dataset

# %%
def is_valid_text(example):
    """Detect if the example contain missing value in text or labels
    """

    return example['text'] is not None and example['labels'] is not None

def dataset_load(path):
    """Load dataset from a path
    """

    dataset = load_dataset('csv', data_files=path)
    dataset = dataset["train"].filter(is_valid_text)
    dataset = dataset.class_encode_column('labels')
    return dataset

# %%
source_dir = '/content/gdrive/MyDrive/Colab_Notebooks/ML-LoRA-E5/'
dataset = dataset_load(path=os.path.join(source_dir, 'twitter_raid_data/raid_twitter_train.csv')) ## change to your dataset
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Filter:   0%|          | 0/228000 [00:00<?, ? examples/s]
# Stringifying the column:   0%|          | 0/228000 [00:00<?, ? examples/s]
# Casting to class labels:   0%|          | 0/228000 [00:00<?, ? examples/s]

# %%
dataset.to_pandas()["labels"].value_counts()
# Out:
# labels
# 1    138000
# 0     90000
# Name: count, dtype: int64

# %% [markdown]
# ## Split data into training and validation/test datasets

# %%
dataset = dataset.train_test_split(test_size=0.2, stratify_by_column='labels', seed = 100) ## set seed for reproducibility
print("Train label distribution:", dataset["train"].to_pandas()["labels"].value_counts())
print("Test label distribution:", dataset["test"].to_pandas()["labels"].value_counts())
# Out:
# Train label distribution: labels
# 1    110400
# 0     72000
# Name: count, dtype: int64
# Test label distribution: labels
# 1    27600
# 0    18000
# Name: count, dtype: int64

# %% [markdown]
# ## Tokenization

# %%
def text_tokenize(dataset, model_name, max_length=512, truncation=True, padding=False):
    """Tokenize dataset using the provided tokenizer.

    Parameters:
    - dataset (Dataset): The dataset to tokenize.
    - model_name (str): The name of the tokenizer to use. Must be a model on https://huggingface.co/models
    - max_length (int, optional): The maximum length of the tokenized text. Defaults to 512.
    - truncation (bool, optional): Whether to truncate the text if it exceeds max_length. Defaults to True.
    - padding (bool, optional): Whether to pad the text to max_length. Defaults to False.

    Returns:
    - tokenized_datasets (DatasetDict): The tokenized dataset.
    - tokenizer (Tokenizer): The tokenizer used for tokenization.
    """
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    def tokenize_function(examples):
        return tokenizer(examples["text"], max_length=max_length, truncation=truncation, padding=padding)
    tokenized_datasets = dataset.map(tokenize_function, batched=True)
    return tokenized_datasets, tokenizer

# %%
tokenized_datasets, tokenizer = text_tokenize(dataset, model_name='intfloat/e5-small')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/362 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Map:   0%|          | 0/182400 [00:00<?, ? examples/s]
# Map:   0%|          | 0/45600 [00:00<?, ? examples/s]

# %%
tokenized_datasets['train']
# Out:
# Dataset({
#     features: ['text', 'domain', 'model', 'attack', 'labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 182400
# })

# %%
tokenized_datasets['test']
# Out:
# Dataset({
#     features: ['text', 'domain', 'model', 'attack', 'labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 45600
# })

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Setup raw model

# %%
model_name = "intfloat/e5-small"
raw_model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)
# Out:
# config.json:   0%|          | 0.00/641 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at intfloat/e5-small and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Check the paramters

# %%
for name, param in raw_model.named_parameters():
    print(f"Parameter: {name} | Requires Grad: {param.requires_grad}")
# Out:
# Parameter: bert.embeddings.word_embeddings.weight | Requires Grad: True
# Parameter: bert.embeddings.position_embeddings.weight | Requires Grad: True
# Parameter: bert.embeddings.token_type_embeddings.weight | Requires Grad: True
# Parameter: bert.embeddings.LayerNorm.weight | Requires Grad: True
# Parameter: bert.embeddings.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.0.attention.self.query.weight | Requires Grad: True
# Parameter: bert.encoder.layer.0.attention.self.query.bias | Requires Grad: True
# Parameter: bert.encoder.layer.0.attention.self.key.weight | Requires Grad: True
# Parameter: bert.encoder.layer.0.attention.self.key.bias | Requires Grad: True
# Parameter: bert.encoder.layer.0.attention.self.value.weight | Requires Grad: True
# Parameter: bert.encoder.layer.0.attention.self.value.bias | Requires Grad: True
# Parameter: bert.encoder.layer.0.attention.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.0.attention.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.0.attention.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.0.attention.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.0.intermediate.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.0.intermediate.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.0.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.0.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.0.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.0.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.1.attention.self.query.weight | Requires Grad: True
# Parameter: bert.encoder.layer.1.attention.self.query.bias | Requires Grad: True
# Parameter: bert.encoder.layer.1.attention.self.key.weight | Requires Grad: True
# Parameter: bert.encoder.layer.1.attention.self.key.bias | Requires Grad: True
# Parameter: bert.encoder.layer.1.attention.self.value.weight | Requires Grad: True
# Parameter: bert.encoder.layer.1.attention.self.value.bias | Requires Grad: True
# Parameter: bert.encoder.layer.1.attention.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.1.attention.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.1.attention.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.1.attention.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.1.intermediate.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.1.intermediate.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.1.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.1.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.1.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.1.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.2.attention.self.query.weight | Requires Grad: True
# Parameter: bert.encoder.layer.2.attention.self.query.bias | Requires Grad: True
# Parameter: bert.encoder.layer.2.attention.self.key.weight | Requires Grad: True
# Parameter: bert.encoder.layer.2.attention.self.key.bias | Requires Grad: True
# Parameter: bert.encoder.layer.2.attention.self.value.weight | Requires Grad: True
# Parameter: bert.encoder.layer.2.attention.self.value.bias | Requires Grad: True
# Parameter: bert.encoder.layer.2.attention.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.2.attention.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.2.attention.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.2.attention.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.2.intermediate.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.2.intermediate.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.2.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.2.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.2.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.2.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.3.attention.self.query.weight | Requires Grad: True
# Parameter: bert.encoder.layer.3.attention.self.query.bias | Requires Grad: True
# Parameter: bert.encoder.layer.3.attention.self.key.weight | Requires Grad: True
# Parameter: bert.encoder.layer.3.attention.self.key.bias | Requires Grad: True
# Parameter: bert.encoder.layer.3.attention.self.value.weight | Requires Grad: True
# Parameter: bert.encoder.layer.3.attention.self.value.bias | Requires Grad: True
# Parameter: bert.encoder.layer.3.attention.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.3.attention.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.3.attention.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.3.attention.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.3.intermediate.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.3.intermediate.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.3.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.3.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.3.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.3.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.4.attention.self.query.weight | Requires Grad: True
# Parameter: bert.encoder.layer.4.attention.self.query.bias | Requires Grad: True
# Parameter: bert.encoder.layer.4.attention.self.key.weight | Requires Grad: True
# Parameter: bert.encoder.layer.4.attention.self.key.bias | Requires Grad: True
# Parameter: bert.encoder.layer.4.attention.self.value.weight | Requires Grad: True
# Parameter: bert.encoder.layer.4.attention.self.value.bias | Requires Grad: True
# Parameter: bert.encoder.layer.4.attention.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.4.attention.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.4.attention.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.4.attention.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.4.intermediate.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.4.intermediate.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.4.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.4.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.4.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.4.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.5.attention.self.query.weight | Requires Grad: True
# Parameter: bert.encoder.layer.5.attention.self.query.bias | Requires Grad: True
# Parameter: bert.encoder.layer.5.attention.self.key.weight | Requires Grad: True
# Parameter: bert.encoder.layer.5.attention.self.key.bias | Requires Grad: True
# Parameter: bert.encoder.layer.5.attention.self.value.weight | Requires Grad: True
# Parameter: bert.encoder.layer.5.attention.self.value.bias | Requires Grad: True
# Parameter: bert.encoder.layer.5.attention.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.5.attention.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.5.attention.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.5.attention.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.5.intermediate.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.5.intermediate.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.5.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.5.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.5.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.5.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.6.attention.self.query.weight | Requires Grad: True
# Parameter: bert.encoder.layer.6.attention.self.query.bias | Requires Grad: True
# Parameter: bert.encoder.layer.6.attention.self.key.weight | Requires Grad: True
# Parameter: bert.encoder.layer.6.attention.self.key.bias | Requires Grad: True
# Parameter: bert.encoder.layer.6.attention.self.value.weight | Requires Grad: True
# Parameter: bert.encoder.layer.6.attention.self.value.bias | Requires Grad: True
# Parameter: bert.encoder.layer.6.attention.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.6.attention.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.6.attention.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.6.attention.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.6.intermediate.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.6.intermediate.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.6.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.6.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.6.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.6.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.7.attention.self.query.weight | Requires Grad: True
# Parameter: bert.encoder.layer.7.attention.self.query.bias | Requires Grad: True
# Parameter: bert.encoder.layer.7.attention.self.key.weight | Requires Grad: True
# Parameter: bert.encoder.layer.7.attention.self.key.bias | Requires Grad: True
# Parameter: bert.encoder.layer.7.attention.self.value.weight | Requires Grad: True
# Parameter: bert.encoder.layer.7.attention.self.value.bias | Requires Grad: True
# Parameter: bert.encoder.layer.7.attention.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.7.attention.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.7.attention.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.7.attention.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.7.intermediate.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.7.intermediate.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.7.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.7.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.7.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.7.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.8.attention.self.query.weight | Requires Grad: True
# Parameter: bert.encoder.layer.8.attention.self.query.bias | Requires Grad: True
# Parameter: bert.encoder.layer.8.attention.self.key.weight | Requires Grad: True
# Parameter: bert.encoder.layer.8.attention.self.key.bias | Requires Grad: True
# Parameter: bert.encoder.layer.8.attention.self.value.weight | Requires Grad: True
# Parameter: bert.encoder.layer.8.attention.self.value.bias | Requires Grad: True
# Parameter: bert.encoder.layer.8.attention.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.8.attention.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.8.attention.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.8.attention.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.8.intermediate.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.8.intermediate.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.8.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.8.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.8.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.8.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.9.attention.self.query.weight | Requires Grad: True
# Parameter: bert.encoder.layer.9.attention.self.query.bias | Requires Grad: True
# Parameter: bert.encoder.layer.9.attention.self.key.weight | Requires Grad: True
# Parameter: bert.encoder.layer.9.attention.self.key.bias | Requires Grad: True
# Parameter: bert.encoder.layer.9.attention.self.value.weight | Requires Grad: True
# Parameter: bert.encoder.layer.9.attention.self.value.bias | Requires Grad: True
# Parameter: bert.encoder.layer.9.attention.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.9.attention.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.9.attention.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.9.attention.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.9.intermediate.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.9.intermediate.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.9.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.9.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.9.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.9.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.10.attention.self.query.weight | Requires Grad: True
# Parameter: bert.encoder.layer.10.attention.self.query.bias | Requires Grad: True
# Parameter: bert.encoder.layer.10.attention.self.key.weight | Requires Grad: True
# Parameter: bert.encoder.layer.10.attention.self.key.bias | Requires Grad: True
# Parameter: bert.encoder.layer.10.attention.self.value.weight | Requires Grad: True
# Parameter: bert.encoder.layer.10.attention.self.value.bias | Requires Grad: True
# Parameter: bert.encoder.layer.10.attention.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.10.attention.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.10.attention.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.10.attention.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.10.intermediate.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.10.intermediate.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.10.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.10.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.10.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.10.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.11.attention.self.query.weight | Requires Grad: True
# Parameter: bert.encoder.layer.11.attention.self.query.bias | Requires Grad: True
# Parameter: bert.encoder.layer.11.attention.self.key.weight | Requires Grad: True
# Parameter: bert.encoder.layer.11.attention.self.key.bias | Requires Grad: True
# Parameter: bert.encoder.layer.11.attention.self.value.weight | Requires Grad: True
# Parameter: bert.encoder.layer.11.attention.self.value.bias | Requires Grad: True
# Parameter: bert.encoder.layer.11.attention.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.11.attention.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.11.attention.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.11.attention.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.encoder.layer.11.intermediate.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.11.intermediate.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.11.output.dense.weight | Requires Grad: True
# Parameter: bert.encoder.layer.11.output.dense.bias | Requires Grad: True
# Parameter: bert.encoder.layer.11.output.LayerNorm.weight | Requires Grad: True
# Parameter: bert.encoder.layer.11.output.LayerNorm.bias | Requires Grad: True
# Parameter: bert.pooler.dense.weight | Requires Grad: True
# Parameter: bert.pooler.dense.bias | Requires Grad: True
# Parameter: classifier.weight | Requires Grad: True
# Parameter: classifier.bias | Requires Grad: True

# %% [markdown]
# ## LoRA configuration

# %%
def lora_model(rank, raw_model, alpha=None, dropout=0.1, modules=None):
    """Define LoRA model

    Parameters:
    - rank: rank of the LoRA model
    - raw_model: the model we want to fine-tune
    - alpha: alpha of the LoRA model
    - dropout: dropout of the LoRA model
    - modules: the modules we want to add LoRA adapter

    Returns:
    - model: the LoRA model obtained from peft.get_peft_model()


    """
    if alpha is None:
        alpha = 2*rank
    lora_config = LoraConfig(
        task_type=TaskType.SEQ_CLS,
        r=rank,  # Low-rank adaptation rank
        lora_alpha=alpha,  # Scaling factor
        lora_dropout=dropout,  # Dropout for LoRA
        target_modules = modules  # NN (layers) components to add LoRA
    )
    model = get_peft_model(raw_model, lora_config)
    return model

# %%
e5_model = lora_model(rank=8, raw_model=raw_model, modules = ['attention.self.query', 'attention.self.key', 'attention.self.value'])

# %% [markdown]
# ### Check the number of trainable parameters

# %%
def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# %%
print_trainable_parameters(e5_model)
# Out:
# trainable params: 221954 || all params: 33582724 || trainable%: 0.6609172025473574

# %% [markdown]
# ### Check parameters

# %%
for name, param in e5_model.named_parameters():
    print(f"Parameter: {name} | Requires Grad: {param.requires_grad}")
# Out:
# Parameter: base_model.model.bert.embeddings.word_embeddings.weight | Requires Grad: False
# Parameter: base_model.model.bert.embeddings.position_embeddings.weight | Requires Grad: False
# Parameter: base_model.model.bert.embeddings.token_type_embeddings.weight | Requires Grad: False
# Parameter: base_model.model.bert.embeddings.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.embeddings.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.attention.self.query.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.attention.self.query.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.attention.self.query.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.0.attention.self.query.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.0.attention.self.key.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.attention.self.key.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.attention.self.key.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.0.attention.self.key.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.0.attention.self.value.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.attention.self.value.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.attention.self.value.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.0.attention.self.value.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.0.attention.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.attention.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.attention.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.attention.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.intermediate.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.intermediate.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.0.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.attention.self.query.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.attention.self.query.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.attention.self.query.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.1.attention.self.query.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.1.attention.self.key.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.attention.self.key.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.attention.self.key.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.1.attention.self.key.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.1.attention.self.value.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.attention.self.value.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.attention.self.value.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.1.attention.self.value.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.1.attention.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.attention.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.attention.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.attention.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.intermediate.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.intermediate.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.1.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.attention.self.query.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.attention.self.query.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.attention.self.query.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.2.attention.self.query.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.2.attention.self.key.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.attention.self.key.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.attention.self.key.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.2.attention.self.key.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.2.attention.self.value.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.attention.self.value.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.attention.self.value.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.2.attention.self.value.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.2.attention.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.attention.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.attention.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.attention.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.intermediate.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.intermediate.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.2.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.attention.self.query.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.attention.self.query.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.attention.self.query.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.3.attention.self.query.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.3.attention.self.key.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.attention.self.key.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.attention.self.key.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.3.attention.self.key.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.3.attention.self.value.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.attention.self.value.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.attention.self.value.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.3.attention.self.value.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.3.attention.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.attention.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.attention.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.attention.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.intermediate.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.intermediate.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.3.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.attention.self.query.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.attention.self.query.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.attention.self.query.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.4.attention.self.query.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.4.attention.self.key.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.attention.self.key.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.attention.self.key.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.4.attention.self.key.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.4.attention.self.value.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.attention.self.value.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.attention.self.value.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.4.attention.self.value.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.4.attention.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.attention.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.attention.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.attention.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.intermediate.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.intermediate.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.4.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.attention.self.query.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.attention.self.query.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.attention.self.query.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.5.attention.self.query.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.5.attention.self.key.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.attention.self.key.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.attention.self.key.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.5.attention.self.key.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.5.attention.self.value.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.attention.self.value.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.attention.self.value.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.5.attention.self.value.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.5.attention.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.attention.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.attention.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.attention.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.intermediate.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.intermediate.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.5.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.attention.self.query.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.attention.self.query.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.attention.self.query.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.6.attention.self.query.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.6.attention.self.key.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.attention.self.key.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.attention.self.key.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.6.attention.self.key.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.6.attention.self.value.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.attention.self.value.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.attention.self.value.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.6.attention.self.value.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.6.attention.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.attention.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.attention.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.attention.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.intermediate.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.intermediate.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.6.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.attention.self.query.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.attention.self.query.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.attention.self.query.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.7.attention.self.query.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.7.attention.self.key.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.attention.self.key.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.attention.self.key.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.7.attention.self.key.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.7.attention.self.value.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.attention.self.value.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.attention.self.value.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.7.attention.self.value.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.7.attention.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.attention.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.attention.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.attention.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.intermediate.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.intermediate.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.7.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.attention.self.query.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.attention.self.query.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.attention.self.query.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.8.attention.self.query.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.8.attention.self.key.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.attention.self.key.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.attention.self.key.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.8.attention.self.key.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.8.attention.self.value.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.attention.self.value.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.attention.self.value.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.8.attention.self.value.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.8.attention.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.attention.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.attention.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.attention.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.intermediate.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.intermediate.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.8.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.attention.self.query.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.attention.self.query.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.attention.self.query.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.9.attention.self.query.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.9.attention.self.key.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.attention.self.key.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.attention.self.key.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.9.attention.self.key.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.9.attention.self.value.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.attention.self.value.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.attention.self.value.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.9.attention.self.value.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.9.attention.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.attention.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.attention.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.attention.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.intermediate.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.intermediate.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.9.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.attention.self.query.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.attention.self.query.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.attention.self.query.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.10.attention.self.query.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.10.attention.self.key.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.attention.self.key.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.attention.self.key.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.10.attention.self.key.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.10.attention.self.value.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.attention.self.value.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.attention.self.value.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.10.attention.self.value.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.10.attention.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.attention.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.attention.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.attention.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.intermediate.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.intermediate.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.10.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.attention.self.query.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.attention.self.query.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.attention.self.query.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.11.attention.self.query.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.11.attention.self.key.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.attention.self.key.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.attention.self.key.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.11.attention.self.key.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.11.attention.self.value.base_layer.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.attention.self.value.base_layer.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.attention.self.value.lora_A.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.11.attention.self.value.lora_B.default.weight | Requires Grad: True
# Parameter: base_model.model.bert.encoder.layer.11.attention.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.attention.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.attention.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.attention.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.intermediate.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.intermediate.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.output.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.output.dense.bias | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.output.LayerNorm.weight | Requires Grad: False
# Parameter: base_model.model.bert.encoder.layer.11.output.LayerNorm.bias | Requires Grad: False
# Parameter: base_model.model.bert.pooler.dense.weight | Requires Grad: False
# Parameter: base_model.model.bert.pooler.dense.bias | Requires Grad: False
# Parameter: base_model.model.classifier.original_module.weight | Requires Grad: False
# Parameter: base_model.model.classifier.original_module.bias | Requires Grad: False
# Parameter: base_model.model.classifier.modules_to_save.default.weight | Requires Grad: True
# Parameter: base_model.model.classifier.modules_to_save.default.bias | Requires Grad: True

# %% [markdown]
# ## LoRA training

# %% [markdown]
# ### Implement Focal Loss
# https://medium.com/visionwizard/understanding-focal-loss-a-quick-read-b914422913e7

# %%
class FocalLoss(torch.nn.Module):
    """Define FocalLoss Class
    """
    def __init__(self, gamma=2.0, alpha=None, reduction='mean'):
       """
       Parameters:
       - gamma: focal loss gamma
       - alpha: focal loss alpha
       - reduction: reduction method for the return loss
       """
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.reduction = reduction

    def forward(self, inputs, targets):
        """
        Parameters:
        - inputs: logits (should be a tensor of size (batch_size, num_classes))
        - targets: labels
        """
        # Compute standard cross entropy
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')

        # Compute the probability of each class for the targets
        pt = torch.exp(-ce_loss)

        # Apply focal loss formula
        focal_loss = ((1 - pt) ** self.gamma) * ce_loss

        # Apply class weights if provided
        if self.alpha is not None:
            alpha_t = self.alpha.gather(0, targets.data.view(-1))
            focal_loss = alpha_t * focal_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %%
class FocalLossTrainer(Trainer):
    """Define FocalLossTrainer Class
    """
    def __init__(self, *args, fl_alpha=None, **kwargs):
        """
        Parameters:
        - fl_alpha: focal loss alpha
        """
        super().__init__(*args, **kwargs)
        self.fl_alpha = fl_alpha if fl_alpha is not None else [0.5,0.5]

    def compute_loss(self, model, inputs, return_outputs=False):
        """
        Parameters:
        - model: model used to compute loss
        - inputs: a dictionary containing the batch data including keys "input_ids", "attention_mask", and "labels"
        - return_outputs: return outputs or not

        """
        labels = inputs.get("labels")
        outputs = model(**inputs)
        logits = outputs.get("logits")

        # Calculate focal loss

        loss_fct = FocalLoss(gamma=2.0, alpha=torch.tensor(self.fl_alpha).to(logits.device))
        loss = loss_fct(logits, labels)

        self.log({"train_loss": loss.item()})
        self.state.log_history.append({"train_loss": loss.item()})

        return (loss, outputs) if return_outputs else loss

# %% [markdown]
# ### Define evaluation metrics

# %%
accuracy_m = evaluate.load('accuracy')
def compute_metrics(eval_pred):
    """Compute evaluation metrics

    Parameters:
    - eval_pred: a tuple containing logits and labels

    Returns:
    - a dictionary containing the evaluation metrics
    """
    logits, labels = eval_pred

    # Convert logits to probabilities for AUC calculation
    probabilities = softmax(logits, axis=-1)

    # Get predicted classes
    predictions = np.argmax(logits, axis=-1)

    # Calculate F1 score
    f1 = f1_score(labels, predictions, average="weighted")

    # Calculate Accuracy
    accuracy = accuracy_m.compute(predictions=predictions, references=labels)

    # Calculate AUC
    # For binary classification, use labels as-is; for multi-class, use `multi_class='ovr'`
    try:
        if probabilities.shape[1] == 2:  # Binary classification
            positive_probs = probabilities[:, 1]
            auc = roc_auc_score(labels, positive_probs)
        else:  # Multi-class classification
            auc = roc_auc_score(labels, probabilities, multi_class='ovr', average='weighted')
    except ValueError:
        # AUC calculation may fail if there's only one class in `labels`
        auc = None

    return {
        "accuracy": accuracy['accuracy'],
        "f1": f1,
        "auc": auc
    }
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %% [markdown]
# ### Define training arguments and trainer

# %%
# define training arguments
training_args = TrainingArguments(
    output_dir=os.path.join(source_dir, 'twitter_raid_data/results_LoRA_e5'),
    overwrite_output_dir=True,
    run_name='LoRA-E5',
    save_strategy="epoch",
    logging_strategy="steps",  # Ensure logging happens at each step
    logging_steps=10,
    evaluation_strategy="epoch",  # Evaluate at the end of each epoch
    #learning_rate=2e-5,
    per_device_train_batch_size=10,  # Training epoch size
    per_device_eval_batch_size=1,  # Evaluation epoch size
    group_by_length=True, # group the tokenized text by length
    num_train_epochs=3
)

# %%
# compute frequency in order to get by class weigth (alpha) in focal loss
freq = [1 - sum(dataset['train']['labels'])/len(dataset['train']['labels']), sum(dataset['train']['labels'])/len(dataset['train']['labels'])]

# %%
# define LoRa trainer
model_name = "intfloat/e5-small"
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
LoRA_trainer = FocalLossTrainer(
    model=e5_model,
    fl_alpha = [1-x for x in freq],
    args=training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['test'],
    data_collator=data_collator,
    compute_metrics=compute_metrics
)

# %% [markdown]
# ## Training

# %%
# set environment
os.environ["WANDB_DISABLED"] = "false"
os.environ["WANDB_MODE"] = "dryrun"

# %%
LoRA_trainer.train()  ## The peformance after the third epoch decrease. We may take the second one as the final model.
# Out:
#     <div>
#
#       <progress value='54720' max='54720' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [54720/54720 1:36:36, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.009100</td>
#       <td>0.064852</td>
#       <td>{'accuracy': 0.8407675438596491}</td>
#       <td>0.831234</td>
#       <td>0.965121</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.007300</td>
#       <td>0.044413</td>
#       <td>{'accuracy': 0.8903070175438597}</td>
#       <td>0.887466</td>
#       <td>0.976069</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.007500</td>
#       <td>0.053699</td>
#       <td>{'accuracy': 0.8796271929824562}</td>
#       <td>0.875316</td>
#       <td>0.976018</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer is attempting to log a value of "{'accuracy': 0.8407675438596491}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.8903070175438597}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.8796271929824562}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# TrainOutput(global_step=54720, training_loss=0.024202585291785966, metrics={'train_runtime': 5796.4135, 'train_samples_per_second': 94.403, 'train_steps_per_second': 9.44, 'total_flos': 2.1538237462044e+16, 'train_loss': 0.024202585291785966, 'epoch': 3.0})

# %% [markdown]
# # Raw Model Training and Evaluation

# %% [markdown]
# ## Freeze all layers except the output layer

# %%
# reload raw model
model_name = "intfloat/e5-small"
raw_model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2) # when calling AutoModelForSequenceClassification, the weights in output layer is randomly initialized
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at intfloat/e5-small and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
for name, param in raw_model.named_parameters():
    if "classifier" not in name:  # Keep only the classifier layer unfrozen
        param.requires_grad = False

# %%
# check the number of trainable parameters in output layer
print_trainable_parameters(raw_model)
# Out:
# trainable params: 770 || all params: 33360770 || trainable%: 0.0023081002027231386

# %% [markdown]
# ## Define training arguments and trainer

# %%
# Define training arguments
training_args = TrainingArguments(
    output_dir=os.path.join(source_dir, 'twitter_raid_data/results_raw_e5'),
    overwrite_output_dir=True,
    run_name='raw-E5',
    save_strategy="epoch",
    logging_strategy="steps",  # Ensure logging happens at each step
    logging_steps=10,
    evaluation_strategy="epoch",  # Evaluate at the end of each epoch
    #learning_rate=2e-5,
    per_device_train_batch_size=10,
    per_device_eval_batch_size=1,
    group_by_length=True,
    num_train_epochs=3
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
# define raw trainer
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
freq = [1 - sum(dataset['train']['labels'])/len(dataset['train']['labels']), sum(dataset['train']['labels'])/len(dataset['train']['labels'])]

raw_trainer = FocalLossTrainer(
    model=raw_model,
    fl_alpha = [1-x for x in freq],
    args=training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['test'],
    data_collator=data_collator,
    compute_metrics=compute_metrics
)

# %% [markdown]
# ## Training

# %%
os.environ["WANDB_DISABLED"] = "false"
os.environ["WANDB_MODE"] = "dryrun"

# %%
raw_trainer.train()
# Out:
#     <div>
#
#       <progress value='54720' max='54720' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [54720/54720 52:02, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.075000</td>
#       <td>0.080048</td>
#       <td>{'accuracy': 0.6316008771929824}</td>
#       <td>0.635702</td>
#       <td>0.691894</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.073800</td>
#       <td>0.079073</td>
#       <td>{'accuracy': 0.6517105263157895}</td>
#       <td>0.652730</td>
#       <td>0.696835</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.073200</td>
#       <td>0.078788</td>
#       <td>{'accuracy': 0.6485745614035088}</td>
#       <td>0.651111</td>
#       <td>0.698270</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer is attempting to log a value of "{'accuracy': 0.6316008771929824}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.6517105263157895}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.6485745614035088}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# TrainOutput(global_step=54720, training_loss=0.08023347747212614, metrics={'train_runtime': 3122.7747, 'train_samples_per_second': 175.229, 'train_steps_per_second': 17.523, 'total_flos': 2.131758110278776e+16, 'train_loss': 0.08023347747212614, 'epoch': 3.0})
